# %% [markdown]
# # Smoke Sensory Python Script
# This script is designed to streamline the data acquisition and mining operation for LAFFORT. The source code herein was made in collaboration with Daniel A. Dycus, Technical Manager for LAFFORTUSA. The purpose of this script is outlined in the following sections of this Jupyter notebook.
#
# * Import the csv file from Pigeonhole. (future instances for application development should use an API)
# * Build a static dataframe.
# * Use a series of nested loops to import data into static dataframe.
# * Output new dataframe for data analysis.
# * Join all frames for master sensory data file for each sensory session i.e. Each sensory session should possess a new dashboard.
# * Export frame to xls format for current developmental needs.
# * Future mission should acquire frame, perform analysis, and present dashboard. (6 month project?)

# %% [markdown]
# ## Pigeonhole
#
# Pigeonhole reports come as xls or pdf. We currently save the files as csv and have not considered scraping the pdf. This should be done in batches in the future. For now, we focus on building a nest which will work for each xls we receive. We typically receive around fourty csv files in each batch. For data analysis, each csv represents all the sensory scores for a particular factor or treatment. In this experiment we capture sensory data from humans who taste the addition of different wine additives on wines made from smoke-exposed grapes.
#
# The csv has a header with the treatment name. First, we acquire the treatment label and will use it as our filename later.

# %%
# Put the pre-requisite libraries here
import pandas as pd 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f75ba827-7faf-4db1-a2fc-6a1c16abe7c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f75ba827-7faf-4db1-a2fc-6a1c16abe7c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CabernetFrancCaseiPlus50ghL.pdf to CabernetFrancCaseiPlus50ghL.pdf
# Saving CabernetFranc-CaseiPlus50ghL.xlsx to CabernetFranc-CaseiPlus50ghL.xlsx
# Saving CabernetFrancCaseiPlus100ghL.pdf to CabernetFrancCaseiPlus100ghL.pdf
# Saving CabernetFranc-CaseiPlus100ghL.xlsx to CabernetFranc-CaseiPlus100ghL.xlsx
# Saving CabernetFrancControl.pdf to CabernetFrancControl.pdf
# Saving CabernetFranc-Control.xlsx to CabernetFranc-Control.xlsx
# Saving CabernetFrancGeosorb50ghL.pdf to CabernetFrancGeosorb50ghL.pdf
# Saving CabernetFranc-Geosorb50ghL.xlsx to CabernetFranc-Geosorb50ghL.xlsx
# Saving CabernetFrancGeosorb100ghL.pdf to CabernetFrancGeosorb100ghL.pdf
# Saving CabernetFranc-Geosorb100ghL.xlsx to CabernetFranc-Geosorb100ghL.xlsx
# Saving CabernetFrancNOBILEAmericanFresh5gL.pdf to CabernetFrancNOBILEAmericanFresh5gL.pdf
# Saving CabernetFrancNOBILE-AmericanFresh5gL.xlsx to CabernetFrancNOBILE-AmericanFresh5gL.xlsx
# Saving CabernetFrancNOBILEAmericanFresh10ghL.pdf to CabernetFrancNOBILEAmericanFresh10ghL.pdf
# Saving CabernetFrancNOBILE-AmericanFresh10ghL.xlsx to CabernetFrancNOBILE-AmericanFresh10ghL.xlsx
# Saving CabernetFrancNOBILEFreshGran24mo5gL.pdf to CabernetFrancNOBILEFreshGran24mo5gL.pdf
# Saving CabernetFrancNOBILE-FreshGran24mo5gL.xlsx to CabernetFrancNOBILE-FreshGran24mo5gL.xlsx
# Saving CabernetFrancNOBILEFreshGran24mo10gL.pdf to CabernetFrancNOBILEFreshGran24mo10gL.pdf
# Saving CabernetFrancNOBILE-FreshGran24mo10gL.xlsx to CabernetFrancNOBILE-FreshGran24mo10gL.xlsx
# Saving CabernetFrancNOBILEP75gL.pdf to CabernetFrancNOBILEP75gL.pdf
# Saving CabernetFrancNOBILE-P75gL.xlsx to CabernetFrancNOBILE-P75gL.xlsx
# Saving CabernetFrancNOBILEP710gL.pdf to CabernetFrancNOBILEP710gL.pdf
# Saving CabernetFrancNOBILE-P710gL.xlsx to CabernetFrancNOBILE-P710gL.xlsx
# Saving CabernetFrancPolylact50ghL.pdf to CabernetFrancPolylact50ghL.pdf
# Saving CabernetFranc-Polylact50ghL.xlsx to CabernetFranc-Polylact50ghL.xlsx
# Saving CabernetFrancPolylact100ghL.pdf to CabernetFrancPolylact100ghL.pdf
# Saving CabernetFranc-Polylact100ghL.xlsx to CabernetFranc-Polylact100ghL.xlsx
# Saving CommercialViabilityofControls.pdf to CommercialViabilityofControls.pdf
# Saving CommercialViabilityofControls.xlsx to CommercialViabilityofControls.xlsx
# Saving CSControl.pdf to CSControl.pdf
# Saving CS-Control.xlsx to CS-Control.xlsx
# Saving CSGeosorb50ghL.pdf to CSGeosorb50ghL.pdf
# Saving CS-Geosorb50ghL.xlsx to CS-Geosorb50ghL.xlsx
# Saving CSGeosorb100ghL.pdf to CSGeosorb100ghL.pdf
# Saving CS-Geosorb100ghL.xlsx to CS-Geosorb100ghL.xlsx
# Saving CSMetschnikowia10ghL.pdf to CSMetschnikowia10ghL.pdf
# Saving CS-Metschnikowia10ghL.xlsx to CS-Metschnikowia10ghL.xlsx
# Saving CSMetschnikowia100ghL.pdf to CSMetschnikowia100ghL.pdf
# Saving CS-Metschnikowia100ghL.xlsx to CS-Metschnikowia100ghL.xlsx
# Saving CSNOBILEBase5gL.pdf to CSNOBILEBase5gL.pdf
# Saving CSNOBILE-Base5gL.xlsx to CSNOBILE-Base5gL.xlsx
# Saving CSNOBILEBase10gL.pdf to CSNOBILEBase10gL.pdf
# Saving CSNOBILE-Base10gL.xlsx to CSNOBILE-Base10gL.xlsx
# Saving CSNOBILEFreshGran24mo5gL.pdf to CSNOBILEFreshGran24mo5gL.pdf
# Saving CSNOBILE-FreshGran24mo5gL.xlsx to CSNOBILE-FreshGran24mo5gL.xlsx
# Saving CSNOBILEFreshGran24mo10gL.pdf to CSNOBILEFreshGran24mo10gL.pdf
# Saving CSNOBILE-FreshGran24mo10gL.xlsx to CSNOBILE-FreshGran24mo10gL.xlsx
# Saving CSNOBILEOriginalSpice5gL.pdf to CSNOBILEOriginalSpice5gL.pdf
# Saving CSNOBILE-OriginalSpice5gL.xlsx to CSNOBILE-OriginalSpice5gL.xlsx
# Saving CSNOBILEOriginalSpice10gL.pdf to CSNOBILEOriginalSpice10gL.pdf
# Saving CSNOBILE-OriginalSpice10gL.xlsx to CSNOBILE-OriginalSpice10gL.xlsx
# Saving CSNOBILESweetVanilla5gL.pdf to CSNOBILESweetVanilla5gL.pdf
# Saving CSNOBILE-SweetVanilla5gL.xlsx to CSNOBILE-SweetVanilla5gL.xlsx
# Saving CSNOBILESweetVanilla10gL.pdf to CSNOBILESweetVanilla10gL.pdf
# Saving CSNOBILE-SweetVanilla10gL.xlsx to CSNOBILE-SweetVanilla10gL.xlsx
# Saving CSSkimMilk2mLL.pdf to CSSkimMilk2mLL.pdf
# Saving CS-SkimMilk2mLL.xlsx to CS-SkimMilk2mLL.xlsx
# Saving CSSkimMilk10mLL.pdf to CSSkimMilk10mLL.pdf
# Saving CS-SkimMilk10mLL.xlsx to CS-SkimMilk10mLL.xlsx
# Saving FeedbackSurvey.pdf to FeedbackSurvey.pdf
# Saving FeedbackSurvey.xlsx to FeedbackSurvey.xlsx
# Saving MerlotControl.pdf to MerlotControl.pdf
# Saving Merlot-Control.xlsx to Merlot-Control.xlsx
# Saving MerlotGeosorb40ghL.pdf to MerlotGeosorb40ghL.pdf
# Saving Merlot-Geosorb40ghL.xlsx to Merlot-Geosorb40ghL.xlsx
# Saving MerlotGeosorb60ghL.pdf to MerlotGeosorb60ghL.pdf
# Saving Merlot-Geosorb60ghL.xlsx to Merlot-Geosorb60ghL.xlsx
# Saving OverallProductPerformance.pdf to OverallProductPerformance.pdf
# Saving OverallProductPerformance.xlsx to OverallProductPerformance.xlsx
# Saving PinotNoirControl.pdf to PinotNoirControl.pdf
# Saving PinotNoir-Control.xlsx to PinotNoir-Control.xlsx
# Saving PinotNoirGeosorb40ghL.pdf to PinotNoirGeosorb40ghL.pdf
# Saving PinotNoir-Geosorb40ghL.xlsx to PinotNoir-Geosorb40ghL.xlsx
# Saving PinotNoirGeosorb60ghL.pdf to PinotNoirGeosorb60ghL.pdf
# Saving PinotNoir-Geosorb60ghL.xlsx to PinotNoir-Geosorb60ghL.xlsx
# Saving PinotNoirYeastDerivativeA50ghL.pdf to PinotNoirYeastDerivativeA50ghL.pdf
# Saving PinotNoir-YeastDerivativeA50ghL.xlsx to PinotNoir-YeastDerivativeA50ghL.xlsx
# Saving PinotNoirYeastDerivativeA100ghL.pdf to PinotNoirYeastDerivativeA100ghL.pdf
# Saving PinotNoir-YeastDerivativeA100ghL.xlsx to PinotNoir-YeastDerivativeA100ghL.xlsx
# Saving PinotNoirYeastDerivativeB50ghL.pdf to PinotNoirYeastDerivativeB50ghL.pdf
# Saving PinotNoir-YeastDerivativeB50ghL.xlsx to PinotNoir-YeastDerivativeB50ghL.xlsx
# Saving PinotNoirYeastDerivativeB100ghL.pdf to PinotNoirYeastDerivativeB100ghL.pdf
# Saving PinotNoir-YeastDerivativeB100ghL.xlsx to PinotNoir-YeastDerivativeB100ghL.xlsx
# Saving PracticeSession.pdf to PracticeSession.pdf
# Saving PracticeSession.xlsx to PracticeSession.xlsx
# Saving ShortQuiz.pdf to ShortQuiz.pdf
# Saving ShortQuiz.xlsx to ShortQuiz.xlsx
# Saving SmokeCharacterCloud.pdf to SmokeCharacterCloud.pdf
# Saving SmokeCharacterCloud.xlsx to SmokeCharacterCloud.xlsx

# %%
import glob
survey_files = glob.glob('*.xlsx')
survey_files
# Out:
# ['PinotNoir-YeastDerivativeA100ghL.xlsx',
#  'Merlot-Control.xlsx',
#  'PinotNoir-YeastDerivativeB50ghL.xlsx',
#  'PracticeSession.xlsx',
#  'CommercialViabilityofControls.xlsx',
#  'CabernetFrancNOBILE-P75gL.xlsx',
#  'PinotNoir-Geosorb60ghL.xlsx',
#  'Merlot-Geosorb40ghL.xlsx',
#  'CSNOBILE-FreshGran24mo5gL.xlsx',
#  'CabernetFranc-Geosorb100ghL.xlsx',
#  'ShortQuiz.xlsx',
#  'CabernetFranc-Polylact50ghL.xlsx',
#  'CabernetFranc-CaseiPlus50ghL.xlsx',
#  'CabernetFrancNOBILE-AmericanFresh10ghL.xlsx',
#  'CS-Geosorb50ghL.xlsx',
#  'CS-Metschnikowia100ghL.xlsx',
#  'CS-Metschnikowia10ghL.xlsx',
#  'OverallProductPerformance.xlsx',
#  'SmokeCharacterCloud.xlsx',
#  'CSNOBILE-FreshGran24mo10gL.xlsx',
#  'CabernetFrancNOBILE-FreshGran24mo5gL.xlsx',
#  'PinotNoir-Geosorb40ghL.xlsx',
#  'CS-SkimMilk2mLL.xlsx',
#  'CabernetFrancNOBILE-P710gL.xlsx',
#  'CabernetFrancNOBILE-FreshGran24mo10gL.xlsx',
#  'FeedbackSurvey.xlsx',
#  'PinotNoir-YeastDerivativeA50ghL.xlsx',
#  'CSNOBILE-SweetVanilla10gL.xlsx',
#  'CSNOBILE-OriginalSpice5gL.xlsx',
#  'CabernetFranc-CaseiPlus100ghL.xlsx',
#  'CabernetFranc-Control.xlsx',
#  'CSNOBILE-OriginalSpice10gL.xlsx',
#  'PinotNoir-YeastDerivativeB100ghL.xlsx',
#  'CSNOBILE-Base5gL.xlsx',
#  'CSNOBILE-SweetVanilla5gL.xlsx',
#  'Merlot-Geosorb60ghL.xlsx',
#  'CabernetFranc-Polylact100ghL.xlsx',
#  'CS-SkimMilk10mLL.xlsx',
#  'PinotNoir-Control.xlsx',
#  'CabernetFranc-Geosorb50ghL.xlsx',
#  'CabernetFrancNOBILE-AmericanFresh5gL.xlsx',
#  'CS-Geosorb100ghL.xlsx',
#  'CS-Control.xlsx',
#  'CSNOBILE-Base10gL.xlsx']

# %%
file_name = "CabernetFranc-CaseiPlus50ghL.xlsx"
def get_raw_dataframe(file_name):
    import os
    survey_name = os.path.splitext(file_name)[0]
    xl_file = pd.ExcelFile(file_name)
    data_raw = {sheet_name: xl_file.parse(sheet_name) 
            for sheet_name in xl_file.sheet_names}
    df_raw = data_raw['Poll By Users']
    return survey_name, df_raw

survey_name, df_raw = get_raw_dataframe(file_name)
df_raw
# Out:
#                                  Pigeonhole Live Poll  ... Unnamed: 96
# 0   325565: Laffort Internal Smoke Sensory Analysi...  ...         NaN
# 1           1539862: Cabernet Franc Casei Plus 50g/hL  ...         NaN
# 2                                                 NaN  ...         NaN
# 3                                                 NaN  ...         NaN
# 4                                           Date/Time  ...         NaN
# 5                                 2021-01-21 12:25:35  ...         NaN
# 6                                 2021-01-21 13:30:14  ...         NaN
# 7                                 2021-01-21 15:12:16  ...         NaN
# 8                                 2021-01-21 19:08:11  ...         NaN
# 9                                 2021-01-22 15:49:05  ...         NaN
# 10                                2021-01-22 15:49:08  ...         NaN
# 11                                2021-01-22 15:54:21  ...         NaN
# 12                                2021-01-23 13:58:00  ...         NaN
# 13                                2021-01-25 08:50:22  ...         NaN
# 14                                2021-01-25 18:50:22  ...         NaN
# 15                                2021-01-25 18:51:28  ...         NaN
#
# [16 rows x 97 columns]

# %% [markdown]
# ## Dataframe
# Our dataframe will have the following sensory attributes rated by each panelist.

# %%
def initial_cleaning(df_raw, rows_to_skip=4, cols_for_user_info=10):
    df=df_raw.drop(range(rows_to_skip))
    #create new header
    new_header = df.iloc[0] #grab the first row for the header
    df=df[1:] #take the data less the header row
    df.columns=new_header #set the header row as the df header
    #Slice the stuff I don't need to iterate over
    df_users_info=df.iloc[:,:cols_for_user_info]
    df_scores=df.iloc[:,cols_for_user_info:]
    df_scores = df_scores == '✓' # print('\u2713')
    return df_users_info, df_scores

df_users_info, df_scores = initial_cleaning(df_raw)
df_scores
# Out:
# 4   Q1: 2  Q1: 3  Q1: 4  Q1: 5  Q1: 6  ...  Q15: 3  Q15: 4  Q15: 6  Q15: 9    NaN
# 5   False   True  False  False  False  ...   False    True   False   False  False
# 6    True  False  False  False  False  ...    True   False   False   False  False
# 7   False  False  False   True  False  ...   False   False    True   False  False
# 8   False  False   True  False  False  ...   False   False   False   False  False
# 9   False  False  False   True  False  ...    True   False   False   False  False
# 10  False  False  False  False   True  ...   False   False   False   False  False
# 11  False  False  False  False   True  ...   False   False   False    True  False
# 12  False  False  False  False  False  ...   False   False   False   False  False
# 13  False  False   True  False  False  ...    True   False   False   False  False
# 14   True  False  False  False  False  ...   False   False   False   False  False
# 15  False  False  False   True  False  ...   False   False   False   False  False
#
# [11 rows x 87 columns]

# %%
def pivot_scores(df_scores, survey_name, total_questions=15, rename_col_names=True):
    df_cols = []
    for question_num in range(1,total_questions+1):
        df_cols.append(f'Q{question_num}')
    
    df_pivot=pd.DataFrame(columns=df_cols, index=df_scores.index.values)
    for question_num in range(1,16):
        for score in range(10):
            if f'Q{question_num}: {score}' in df_scores.columns:
                for row in df_scores.index.values:
                    if df_scores[f'Q{question_num}: {score}'][row]==True:
                        # print(df[f'Q{q}: {score}'][row])
                        # print(f'Q{q}: {score}')
                        df_pivot[f'Q{question_num}'][row] = score

    df_cleaned = pd.concat([df_users_info, df_pivot], axis=1)
    df_cleaned["survey_name"] = survey_name
    df_cleaned["wine_type"] = survey_name.split("-")[0]
    df_cleaned["treatment"] = survey_name.split("-")[1]
    survey_name_df = df_cleaned.pop("survey_name")
    df_cleaned.insert(0, "survey_name", survey_name_df)

    if rename_col_names:
        questions=['Aroma|Fruity','Aroma|Herbaceous','Aroma|Smoky','Aroma|Ashy','Aroma|Tar', 
                'Flavor|Fruity', 'Flavor|Herbaceous','Flavor|Smoky','Flavor|Ashy', 'Flavor|Tar', 
                'Mouthfeel|Astringent','Mouthfeel|Bitter','Mouthfeel|Round','Mouthfeel|Lingering Ash','Mouthfeel|Metallic']
        i = 0
        for question_num in range(1,total_questions+1):
            df_cleaned = df_cleaned.rename(columns={f'Q{question_num}':questions[i]})
            i += 1
        
    return df_pivot, df_cleaned

df_pivot, df_cleaned = pivot_scores(df_scores, survey_name)
df_cleaned
# Out:
#           survey_name            Date/Time  ... wine_type treatment
# 5   CSNOBILE-Base10gL  2021-01-22 14:34:09  ...  CSNOBILE  Base10gL
# 6   CSNOBILE-Base10gL  2021-01-22 14:40:35  ...  CSNOBILE  Base10gL
# 7   CSNOBILE-Base10gL  2021-01-22 14:41:04  ...  CSNOBILE  Base10gL
# 8   CSNOBILE-Base10gL  2021-01-22 16:36:17  ...  CSNOBILE  Base10gL
# 9   CSNOBILE-Base10gL  2021-01-22 18:54:16  ...  CSNOBILE  Base10gL
# 10  CSNOBILE-Base10gL  2021-01-24 13:53:11  ...  CSNOBILE  Base10gL
# 11  CSNOBILE-Base10gL  2021-01-24 15:42:03  ...  CSNOBILE  Base10gL
# 12  CSNOBILE-Base10gL  2021-01-25 14:19:15  ...  CSNOBILE  Base10gL
# 13  CSNOBILE-Base10gL  2021-01-25 20:18:03  ...  CSNOBILE  Base10gL
#
# [9 rows x 28 columns]

# %% [markdown]
# ## Main Function
# To process all the files in the directory and clean them all and create a "MASTER DATASET".

# %%
survey_master_dataset = pd.DataFrame()
list_of_num_participants = []
list_of_num_questions = []
surveys_meta = pd.DataFrame(columns=["survey_name", "wine_type", "treatment", "num_participants", "num_questions"])

for file_name in survey_files:
    print(file_name)
    if file_name in ["OverallProductPerformance.xlsx", "SmokeCharacterCloud.xlsx", "FeedbackSurvey.xlsx", "CommercialViabilityofControls.xlsx", "PracticeSession.xlsx", "ShortQuiz.xlsx"]:
        print("PASSED THIS FILE ------------")
        continue
    survey_name, df_raw = get_raw_dataframe(file_name=file_name)
    df_users_info, df_scores = initial_cleaning(df_raw)
    df_pivot, df_cleaned = pivot_scores(df_scores, survey_name)
    survey_master_dataset = pd.concat([survey_master_dataset, df_cleaned])
    
    # below we wanna know more about what each file contains: how many participants and how many questions in each survey
    num_participants = df_pivot.shape[0]
    num_questions = df_pivot.shape[1]
    print(f": number_of_participants={num_participants}, " + f": number_of_questions={num_questions}")
    if num_participants not in list_of_num_participants:    
        list_of_num_participants.append(num_participants)
    if num_questions not in list_of_num_questions:    
        list_of_num_questions.append(num_questions)
    
    survey_info = pd.DataFrame(data={"survey_name": [survey_name], "wine_type": [survey_name.split("-")[0]], "treatment": [survey_name.split("-")[1]], 
                                     "num_participants": [num_participants], "num_questions": [num_questions]})
    surveys_meta = pd.concat([surveys_meta, survey_info]).reset_index(drop=True)
# Out:
# PinotNoir-YeastDerivativeA100ghL.xlsx
# : number_of_participants=16, : number_of_questions=15
# Merlot-Control.xlsx
# : number_of_participants=11, : number_of_questions=15
# PinotNoir-YeastDerivativeB50ghL.xlsx
# : number_of_participants=16, : number_of_questions=15
# PracticeSession.xlsx
# PASSED THIS FILE ------------
# CommercialViabilityofControls.xlsx
# PASSED THIS FILE ------------
# CabernetFrancNOBILE-P75gL.xlsx
# : number_of_participants=11, : number_of_questions=15
# PinotNoir-Geosorb60ghL.xlsx
# : number_of_participants=16, : number_of_questions=15
# Merlot-Geosorb40ghL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CSNOBILE-FreshGran24mo5gL.xlsx
# : number_of_participants=9, : number_of_questions=15
# CabernetFranc-Geosorb100ghL.xlsx
# : number_of_participants=11, : number_of_questions=15
# ShortQuiz.xlsx
# PASSED THIS FILE ------------
# CabernetFranc-Polylact50ghL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CabernetFranc-CaseiPlus50ghL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CabernetFrancNOBILE-AmericanFresh10ghL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CS-Geosorb50ghL.xlsx
# : number_of_participants=10, : number_of_questions=15
# CS-Metschnikowia100ghL.xlsx
# : number_of_participants=10, : number_of_questions=15
# CS-Metschnikowia10ghL.xlsx
# : number_of_participants=10, : number_of_questions=15
# OverallProductPerformance.xlsx
# PASSED THIS FILE ------------
# SmokeCharacterCloud.xlsx
# PASSED THIS FILE ------------
# CSNOBILE-FreshGran24mo10gL.xlsx
# : number_of_participants=9, : number_of_questions=15
# CabernetFrancNOBILE-FreshGran24mo5gL.xlsx
# : number_of_participants=11, : number_of_questions=15
# PinotNoir-Geosorb40ghL.xlsx
# : number_of_participants=16, : number_of_questions=15
# CS-SkimMilk2mLL.xlsx
# : number_of_participants=10, : number_of_questions=15
# CabernetFrancNOBILE-P710gL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CabernetFrancNOBILE-FreshGran24mo10gL.xlsx
# : number_of_participants=11, : number_of_questions=15
# FeedbackSurvey.xlsx
# PASSED THIS FILE ------------
# PinotNoir-YeastDerivativeA50ghL.xlsx
# : number_of_participants=16, : number_of_questions=15
# CSNOBILE-SweetVanilla10gL.xlsx
# : number_of_participants=9, : number_of_questions=15
# CSNOBILE-OriginalSpice5gL.xlsx
# : number_of_participants=9, : number_of_questions=15
# CabernetFranc-CaseiPlus100ghL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CabernetFranc-Control.xlsx
# : number_of_participants=11, : number_of_questions=15
# CSNOBILE-OriginalSpice10gL.xlsx
# : number_of_participants=9, : number_of_questions=15
# PinotNoir-YeastDerivativeB100ghL.xlsx
# : number_of_participants=16, : number_of_questions=15
# CSNOBILE-Base5gL.xlsx
# : number_of_participants=9, : number_of_questions=15
# CSNOBILE-SweetVanilla5gL.xlsx
# : number_of_participants=9, : number_of_questions=15
# Merlot-Geosorb60ghL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CabernetFranc-Polylact100ghL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CS-SkimMilk10mLL.xlsx
# : number_of_participants=9, : number_of_questions=15
# PinotNoir-Control.xlsx
# : number_of_participants=16, : number_of_questions=15
# CabernetFranc-Geosorb50ghL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CabernetFrancNOBILE-AmericanFresh5gL.xlsx
# : number_of_participants=11, : number_of_questions=15
# CS-Geosorb100ghL.xlsx
# : number_of_participants=10, : number_of_questions=15
# CS-Control.xlsx
# : number_of_participants=10, : number_of_questions=15
# CSNOBILE-Base10gL.xlsx
# : number_of_participants=9, : number_of_questions=15

# %%
list_of_num_questions
# Out:
# [15]

# %%
list_of_num_participants
# Out:
# [16, 11, 9, 10]

# %%
surveys_meta
# Out:
#                                survey_name  ... num_questions
# 0         PinotNoir-YeastDerivativeA100ghL  ...            15
# 1                           Merlot-Control  ...            15
# 2          PinotNoir-YeastDerivativeB50ghL  ...            15
# 3                CabernetFrancNOBILE-P75gL  ...            15
# 4                   PinotNoir-Geosorb60ghL  ...            15
# 5                      Merlot-Geosorb40ghL  ...            15
# 6                CSNOBILE-FreshGran24mo5gL  ...            15
# 7              CabernetFranc-Geosorb100ghL  ...            15
# 8              CabernetFranc-Polylact50ghL  ...            15
# 9             CabernetFranc-CaseiPlus50ghL  ...            15
# 10  CabernetFrancNOBILE-AmericanFresh10ghL  ...            15
# 11                         CS-Geosorb50ghL  ...            15
# 12                  CS-Metschnikowia100ghL  ...            15
# 13                   CS-Metschnikowia10ghL  ...            15
# 14              CSNOBILE-FreshGran24mo10gL  ...            15
# 15    CabernetFrancNOBILE-FreshGran24mo5gL  ...            15
# 16                  PinotNoir-Geosorb40ghL  ...            15
# 17                         CS-SkimMilk2mLL  ...            15
# 18              CabernetFrancNOBILE-P710gL  ...            15
# 19   CabernetFrancNOBILE-FreshGran24mo10gL  ...            15
# 20         PinotNoir-YeastDerivativeA50ghL  ...            15
# 21               CSNOBILE-SweetVanilla10gL  ...            15
# 22               CSNOBILE-OriginalSpice5gL  ...            15
# 23           CabernetFranc-CaseiPlus100ghL  ...            15
# 24                   CabernetFranc-Control  ...            15
# 25              CSNOBILE-OriginalSpice10gL  ...            15
# 26        PinotNoir-YeastDerivativeB100ghL  ...            15
# 27                        CSNOBILE-Base5gL  ...            15
# 28                CSNOBILE-SweetVanilla5gL  ...            15
# 29                     Merlot-Geosorb60ghL  ...            15
# 30            CabernetFranc-Polylact100ghL  ...            15
# 31                        CS-SkimMilk10mLL  ...            15
# 32                       PinotNoir-Control  ...            15
# 33              CabernetFranc-Geosorb50ghL  ...            15
# 34    CabernetFrancNOBILE-AmericanFresh5gL  ...            15
# 35                        CS-Geosorb100ghL  ...            15
# 36                              CS-Control  ...            15
# 37                       CSNOBILE-Base10gL  ...            15
#
# [38 rows x 5 columns]

# %%
survey_master_dataset
# Out:
#                          survey_name  ...               treatment
# 5   PinotNoir-YeastDerivativeA100ghL  ...  YeastDerivativeA100ghL
# 6   PinotNoir-YeastDerivativeA100ghL  ...  YeastDerivativeA100ghL
# 7   PinotNoir-YeastDerivativeA100ghL  ...  YeastDerivativeA100ghL
# 8   PinotNoir-YeastDerivativeA100ghL  ...  YeastDerivativeA100ghL
# 9   PinotNoir-YeastDerivativeA100ghL  ...  YeastDerivativeA100ghL
# ..                               ...  ...                     ...
# 9                  CSNOBILE-Base10gL  ...                Base10gL
# 10                 CSNOBILE-Base10gL  ...                Base10gL
# 11                 CSNOBILE-Base10gL  ...                Base10gL
# 12                 CSNOBILE-Base10gL  ...                Base10gL
# 13                 CSNOBILE-Base10gL  ...                Base10gL
#
# [429 rows x 28 columns]

# %%
# authenticate
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials as GC
gc = gspread.authorize(GC.get_application_default())
# create, and save df
from gspread_dataframe import set_with_dataframe
title = 'Wine Sensory'
gc.create(title)  # if not exist
sheet = gc.open(title).sheet1
# include_index=False, include_column_header=True, resize=False
set_with_dataframe(sheet, survey_master_dataset)
